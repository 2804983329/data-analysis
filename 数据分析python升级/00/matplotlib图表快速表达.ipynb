# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

sns.set_style("darkgrid")
sns.set_context("paper")
#设置风格、尺度

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.DataFrame(np.random.randn(1000, 4), index=pd.date_range('1/1/2000',periods=1000), columns=list('ABCD'))
df = df.cumsum()
df.plot(kind='line',   #bar 柱状图  line折线图
        style = '--',
        alpha = 0.4,
        use_index = True, #是否使用坐标
        rot = 45,    #是否旋转
        grid = True, #是否格网图
        figsize = (8,4),  #图的大小
        title = 'test',
        legend = True,
        subplots = False,
        colormap = 'Greens')

# %%
#散点图 、 气泡图

plt.figure(figsize=(8,6))
x = np.random.randn(1000)
y = np.random.randn(1000)
plt.scatter(x,y,marker='.',
            s = np.random.randn(1000)*100,
            cmap = 'Reds',
            c = y,
            alpha=0.8)
#s:散点的大小
#c:散点的颜色
#vmin，vmax：亮度设置，标量
#cmap：colormap

# %%
#箱型图

df = pd.DataFrame(np.random.rand(10,2), columns=['Col1', 'Col2'])
df['X'] = pd.Series(['A','A','A','A','A','B','B','B','B','B'])
df['Y'] = pd.Series(['A','B','A','B','A','B','A','B','A','B'])
print(df.head())
df.boxplot(by= 'X')
df.boxplot(column=['Col1','Col2'], by=['X','Y'])
#columns:按照数据的列分子图
#by：按照列分组做箱型图
# Out:
#        Col1      Col2  X  Y
# 0  0.300578  0.170112  A  A
# 1  0.598947  0.966773  A  B
# 2  0.157483  0.387806  A  A
# 3  0.018586  0.530563  A  B
# 4  0.012616  0.787954  A  A
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000017429A7BFC8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000017429CC23C8>],
#       dtype=object)

# %%
#小提琴图

tips = sns.load_dataset("tips")
print(tips.head())
#加载数据

sns.violinplot(x="day", y="total_bill", data=tips,
               linewidth=2, #线宽
               width= 0.8, #箱之间的间隔比例
               palette= 'hls', #设置调色板
               order = ['Thur','Fri','Sat','Sun'], #筛选类型
               scale = 'area',  #测度小提琴图的宽度：area-面积相同，count-按照样本数量决定宽度，width-宽度一样
               gridsize = 50, #设置小提琴图边线的平滑度，越高越平滑
               inner= 'box', #设置内部显示类型 → “box” ， “quartile” ， “point”， “stick” ，
              )
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#两个样本数据密度分布图

rs = np.random.RandomState(2)  #设定随机数种子
df = pd.DataFrame(rs.randn(100,2),
                  columns = ['A','B'])
sns.kdeplot(df['A'],df['B'],
            char = True,  #是否显示颜色图例
            shade= True, #是否填充
            cmap = 'Reds', #设置调色盘
            shade_lowest=False, #最外层颜色是否显示
            n_levels= 10 #曲线个数，（如果非常多，则会越平滑）
            )
#两个维度数据生成曲线密度图，以颜色作为密度衰减显示

sns.rugplot(df['A'], color='g', axis='x',alpha=0.5)
sns.rugplot(df['B'], color='r', axis='y',alpha=0.5)
#注意设置x，y轴
